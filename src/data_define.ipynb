# %%
from pathlib import Path

# 資料集根目錄
dataset_root = Path("data/archive/marine debris images dataset")

train_dir = dataset_root / "train"
valid_dir = dataset_root / "valid"

# 常見圖片格式
image_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}

def count_images(folder):
    count = 0

    for file in folder.rglob("*"):
        if file.suffix.lower() in image_extensions:
            count += 1

    return count

train_count = count_images(train_dir)
valid_count = count_images(valid_dir)

print("=" * 40)
print("Marine Debris Dataset Audit")
print("=" * 40)
print(f"Train Images : {train_count}")
print(f"Valid Images : {valid_count}")
print(f"Total Images : {train_count + valid_count}")
print("=" * 40)
# Out:
# Running cells with '.venv (3.12.13) (Python 3.12.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/kaine/Desktop/Projects/marine-debris-detector/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
